# %% [markdown]
# # 01 – Data Exploration
#
# Placeholder notebook for exploratory analysis of the hospital readmissions dataset.
# Use the production modules from `src/` rather than re-implementing logic.

# %%
from src.data.ingestion import load_raw_data
from src.data.validation import run_data_quality_checks

df = load_raw_data()
report = run_data_quality_checks(df)
report.print_report()
